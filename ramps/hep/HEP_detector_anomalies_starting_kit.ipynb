# %% [markdown]
# # [Paris Saclay Center for Data Science](http://www.datascience-paris-saclay.fr/)
#
# # RAMP on detector anomaly detection
#
# <i>James Catmore (UOslo), Imad Chaabane (LRI/UPSud), Sergei Gleyzer (UFlorida), Cécile Germain (LRI/UPSud), Isabelle Guyon (LRI/UPSud), Victor Estrade (LRI/UPSud), Balazs Kegl (LAL/CNRS), Edouard Leicht (LAL/CNRS), Gilles Louppe (NYU), David Rousseau (LAL/CNRS), Jean-Roch Vlimant (CalTech)</i>

# %% [markdown]
# <h2>Introduction</h2>
#
# Anomaly detection, where we seek to identify events or datasets that deviate from those normally encountered, is a common task in experimental particle physics. For example, two runs recorded on the same day with identical accelerator and detector conditions and the same trigger menu should not be distinguishable statistically. If they are, some unexpected systematic effect must be present which acts to skew each event or a subset of the events, leading to a collective anomaly. There are many ways in which such problems can arise: for instance, the data acquisition or reconstruction software might be misconfigured, or some subcomponent of the detector might be malfunctioning.
#
# Conversely, an otherwise normal dataset may contain individual events which are somehow unusual. These point anomalies may arise due to a problem with the detector, data acquisition, trigger or reconstruction that only occur in very rare circumstances.
#
# For both cases it would be highly desirable to devise a mechanism that could automatically scan all new datasets, detect any anomalous features, and alert a human being to enable detailed investigation. This is the subject of today's RAMP.
#
#
#
# <h3>The prediction task</h3>
#
# The nature of the challenge is to devise a classifier that can distinguish the anomalous cases from the bulk of the data in a test dataset, having first trained the classifier on a test dataset. Whilst the anomalous events are labelled in the training set, no distinction is made between the different types of distortion.
#
# <b>The challenge in this RAMP is to Separate a skewed data point from a original data point</b>
#
# <h2>Data</h2>
#
# A version of the <a href="http://opendata.cern.ch/collection/ATLAS-Higgs-Challenge-2014?ln=en">HiggsML dataset</a> (used in the <a href="https://higgsml.lal.in2p3.fr/">Kaggle Challenge</a> in 2014) is provided. It contains a mixture of Higgs particles decaying into tau pairs and the principal background processes. The bulk of the events are unchanged, but a significant minority have been artificially distorted or corrupted in some way. These anomalies include:
# <ul>
# <li>abnormal value for the pseudorapidity (eta) for the tau candidates
# <li>lepton transverse momentum scaled by a factor 10
# <li>missing transverse energy increased by a factor 10
# <li>lepton and tau phi values switched.
# </ul>
#
# The full dataset contains approximately 800K events.
# We are giving you 100k events to build models and will use the rest to test them.

# %% [markdown]
# ### Requirements
#
# * numpy>=1.10.0
# * matplotlib>=1.5.0
# * pandas>=0.17.0
# * scikit-learn>=0.17 (different syntaxes for v0.17 and v0.18)

# %%
# %matplotlib inline
from __future__ import division, print_function
import os
import sys
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try :
    import seaborn as sns; sns.set()
except ImportError:
    print("seaborn not found on your computer. "
          "Install it if you want pretty charts \n"
          "If you have internet access you can run in a cell : \n"
          "!pip install -U seaborn ")

pd.set_option('display.max_columns', None)

# %%
# %matplotlib inline

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Loading the data

# %%
data = pd.read_csv('public_train.csv.gz', compression='gzip')
X_df = data.drop(['isSkewed'], axis=1)
Y_df = Y_df = data[['isSkewed']]

# %%
data.head()
# Out:
#    DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  DER_deltar_tau_lep  \
# 0                        1.937        64.546    41.791               2.301
# 1                       69.892        61.447   157.875               1.618
# 2                        4.252        73.423    56.958               3.018
# 3                       76.695        60.761     1.770               2.077
# 4                       21.288        60.049    13.166               2.966
#
#    DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  DER_met_phi_centrality  \
# 0       7.975     105.305                 0.926                   1.087
# 1       2.756     238.670                 1.239                   1.311
# 2      77.300     266.566                 0.823                  -0.622
# 3       1.770      70.690                 1.578                  -1.381
# 4      71.566     265.146                 0.826                   1.393
#
#    PRI_tau_pt  PRI_tau_eta  PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  \
# 0      36.259       -2.248       -2.239      33.582       -1.893        0.035
# 1      36.622        1.748        1.720      45.385        1.078       -3.090
# 2      40.520        1.337        0.564      33.370        1.373       -2.701
# 3      27.419       -0.512        0.345      43.271       -0.025        2.365
# 4      32.143        1.651       -0.056      26.566        2.164        2.866
#
#    PRI_met  PRI_met_phi  isSkewed
# 0   19.872       -0.040         0
# 1  100.619        2.807         1
# 2   64.063       -2.609         0
# 3   38.189       -1.453         1
# 4    4.801        0.406         1

# %% [markdown]
# ## Feature description
#
# - **DER_mass_transverse_met_lep:** The transverse mass between the missing transverse energy and the lepton.
#
# - **DER_mass_vis:** The invariant mass of the hadronic tau and the lepton.
#
# - **DER_pt_h:** The modulus of the vector sum of the transverse momentum of the hadronic tau, the lepton, and the missing transverse energy vector.
#
#
# - **DER_deltar_tau_lep:** The R separation between the hadronic tau and the lepton.
#
# - **DER_pt_tot:** The modulus of the vector sum of the missing transverse momenta and the transverse momenta of the hadronic tau, the lepton, the leading jet (if PRI_jet_num $\geq$) and the subleading jet (if PRI jet num = 2) (but not of any additional jets).
#
# - **DER_sum_pt:** The sum of the moduli of the transverse momenta of the hadronic tau, the lepton, the leading jet (if PRI jet num $\geq$ 1) and the subleading jet (if PRI jet num = 2) and the other jets (if PRI jet num = 3).
#
# - **DER_pt_ratio_lep_tau:** The ratio of the transverse momenta of the lepton and the hadronic tau.
#
# - **DER_met_phi_centrality:** The centrality of the azimuthal angle of the missing transverse energy vector w.r.t. the hadronic tau and the lepton.
#
# - **PRI_tau_pt:** The transverse momentum $\sqrt{p^{2}_{x} + p^{2}_{y}}$ of the hadronic tau.
#
# - **PRI_tau_eta:** The pseudorapidity $\eta$ of the hadronic tau.
#
# - **PRI_tau_phi:** The azimuth angle $\phi$ of the hadronic tau.
#
# - **PRI_lep_pt:** The transverse momentum $\sqrt{p^{2}_{x} + p^{2}_{y}}$ of the lepton (electron or muon).
#
# - **PRI_lep_eta:** The pseudorapidity $\eta$ of the lepton.
#
# - **PRI_lep_phi:** The azimuth angle $\phi$ of the lepton.
#
# - **PRI_met:** The missing transverse energy $\overrightarrow{E}^{miss}_{T}$
#
# - **PRI_met_phi:** The azimuth angle $\phi$ of the mssing transverse energy
#
# - **isSkewed:** The event origin, 0: original distribution ; 1: skewed distribution .

# %% [markdown]
# Check for missing values

# %%
(X_df == -999.).any()
# Out:
# DER_mass_transverse_met_lep    False
# DER_mass_vis                   False
# DER_pt_h                       False
# DER_deltar_tau_lep             False
# DER_pt_tot                     False
# DER_sum_pt                     False
# DER_pt_ratio_lep_tau           False
# DER_met_phi_centrality         False
# PRI_tau_pt                     False
# PRI_tau_eta                    False
# PRI_tau_phi                    False
# PRI_lep_pt                     False
# PRI_lep_eta                    False
# PRI_lep_phi                    False
# PRI_met                        False
# PRI_met_phi                    False
# dtype: bool

# %%
Y_df.head()
# Out:
#    isSkewed
# 0         0
# 1         1
# 2         0
# 3         1
# 4         1

# %%
X_df.head()
# Out:
#    DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  DER_deltar_tau_lep  \
# 0                        1.937        64.546    41.791               2.301
# 1                       69.892        61.447   157.875               1.618
# 2                        4.252        73.423    56.958               3.018
# 3                       76.695        60.761     1.770               2.077
# 4                       21.288        60.049    13.166               2.966
#
#    DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  DER_met_phi_centrality  \
# 0       7.975     105.305                 0.926                   1.087
# 1       2.756     238.670                 1.239                   1.311
# 2      77.300     266.566                 0.823                  -0.622
# 3       1.770      70.690                 1.578                  -1.381
# 4      71.566     265.146                 0.826                   1.393
#
#    PRI_tau_pt  PRI_tau_eta  PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  \
# 0      36.259       -2.248       -2.239      33.582       -1.893        0.035
# 1      36.622        1.748        1.720      45.385        1.078       -3.090
# 2      40.520        1.337        0.564      33.370        1.373       -2.701
# 3      27.419       -0.512        0.345      43.271       -0.025        2.365
# 4      32.143        1.651       -0.056      26.566        2.164        2.866
#
#    PRI_met  PRI_met_phi
# 0   19.872       -0.040
# 1  100.619        2.807
# 2   64.063       -2.609
# 3   38.189       -1.453
# 4    4.801        0.406

# %%
X_df.describe()
# Out:
#        DER_mass_transverse_met_lep   DER_mass_vis       DER_pt_h  \
# count                100000.000000  100000.000000  100000.000000
# mean                     52.618045      89.843398      69.149389
# std                      43.007245      61.979805      95.653894
# min                       0.000000       7.334000       0.001000
# 25%                      20.027000      60.711000      16.690000
# 50%                      47.998000      75.786500      41.547000
# 75%                      75.571250      96.855250      86.094750
# max                    1318.682000    2145.712000    3157.497000
#
#        DER_deltar_tau_lep     DER_pt_tot     DER_sum_pt  DER_pt_ratio_lep_tau  \
# count       100000.000000  100000.000000  100000.000000         100000.000000
# mean             2.402999      30.190263     169.935810              1.708225
# std              0.815938      73.043256     138.721865              2.419824
# min              0.228000       0.001000      46.286000              0.045000
# 25%              1.824000       3.419000      79.044000              0.872000
# 50%              2.507000      16.009500     124.444000              1.269000
# 75%              2.979000      29.946000     211.277000              1.788000
# max              6.025000    2656.503000    3563.050000             99.890000
#
#        DER_met_phi_centrality     PRI_tau_pt    PRI_tau_eta    PRI_tau_phi  \
# count           100000.000000  100000.000000  100000.000000  100000.000000
# mean                -0.130873      39.717522       0.056565      -0.002615
# std                  1.194250      23.316137       1.277961       1.816882
# min                 -1.414000      20.000000      -2.496000      -3.142000
# 25%                 -1.371000      25.198000      -0.903000      -1.576000
# 50%                 -0.366000      32.537000       0.024000      -0.014000
# 75%                  1.227000      46.037500       0.983000       1.577000
# max                  1.414000     654.005000       2.800000       3.142000
#
#           PRI_lep_pt    PRI_lep_eta    PRI_lep_phi        PRI_met  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       57.103112      -0.022483       0.044010      42.841581
# std        76.709654       1.267831       1.817974      33.370627
# min        26.000000      -2.494000      -3.142000       0.158000
# 25%        32.540000      -1.018000      -1.518250      21.760000
# 50%        40.983000      -0.051000       0.081000      35.426000
# 75%        54.724250       0.958000       1.619000      53.529250
# max      2985.960000       2.497000       3.141000     951.363000
#
#          PRI_met_phi
# count  100000.000000
# mean       -0.010388
# std         1.812210
# min        -3.141000
# 25%        -1.574000
# 50%        -0.015000
# 75%         1.564000
# max         3.142000

# %%
X_df.hist(figsize=(15, 20), bins=20);

# %% [markdown]
# Look at the distribution difference between the *original* and *skewed* data on each feature.

# %%
# Choose a feauture to look at :
X_origin = X_df.values[np.where(Y_df==0)[0]]
X_skewed = X_df.values[np.where(Y_df==1)[0]]

n_features = X_df.shape[1]
fig, axes = plt.subplots(int(np.ceil(n_features//4)), 4, figsize=(15,20))
axes = axes.ravel()
for i in range(n_features):
    axes[i].hist([X_origin[:, i], X_skewed[:, i]], bins=20, label=['Original', 'Skewed']);
    axes[i].set_title(X_df.columns[i])
    axes[i].legend(loc=1)

# %% [markdown]
# ## Prediction model
# We are going to follow the scikit-learn API specs.
# Basically,
# - inherit from `BaseEstimator`,
# - initiate all of the arguments and configurations in the `__init__()` function,
# - implement a `fit()` and  a `predict()` function.
#
# More information in the [official documentation](http://scikit-learn.org/stable/developers/contributing.html#apis-of-scikit-learn-objects).

# %% [markdown]
# ## Submission
#
# For your submissions, you have to write 1 classe, saved in 1 file:
# * a class <code>Classification</code> to predict the origin of the example (original or skewed).
#
# When submitting this file (copy-paste on the web interface of the RAMP), they are uploaded to our servers and run to give you a score!

# %%
from sklearn.base import BaseEstimator
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
import numpy as np
from sklearn.calibration import CalibratedClassifierCV
 
class Classifier(BaseEstimator):
    def __init__(self):
        pass
    
    def fit(self, X, y):
        #recompute mt and compare with original
        #new_X=np.abs(np.sqrt(2*X['PRI_lep_pt']*X['PRI_met']*
        #                            (1-np.cos(X['PRI_lep_phi']-X['PRI_met_phi'])))-
        #                    X['DER_mass_transverse_met_lep'])
        new_X=np.abs(np.sqrt(2*X[:, 11]*X[:, 14]*
                                    (1-np.cos(X[:, 13]-X[:, 15])))-
                            X[:, 0])
        X = np.concatenate((X,new_X[:, np.newaxis]), axis=1)
 
        self.clf = CalibratedClassifierCV(
            AdaBoostClassifier(n_estimators=20,base_estimator=DecisionTreeClassifier(max_leaf_nodes=5)),
            method='isotonic'
        )
        return self.clf.fit(X, y)
    
    def predict(self, X):
        #recompute mt and compare with original
        new_X=np.abs(np.sqrt(2*X[:, 11]*X[:, 14]*
                                    (1-np.cos(X[:, 13]-X[:, 15])))-
                            X[:, 0])
        X = np.concatenate((X,new_X[:, np.newaxis]), axis=1)
        
        return self.clf.predict(X)
    
    def predict_proba(self, X):
        #recompute mt and compare with original
        new_X=np.abs(np.sqrt(2*X[:, 11]*X[:, 14]*
                                    (1-np.cos(X[:, 13]-X[:, 15])))-
                            X[:, 0])
        X = np.concatenate((X,new_X[:, np.newaxis]), axis=1)
            
            
        return self.clf.predict_proba(X)

# %% [markdown]
# ### Classifier

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier 
from sklearn.pipeline import make_pipeline

from sklearn.base import BaseEstimator
from sklearn.naive_bayes import GaussianNB

import tensorflow as tf
import numpy as np

def elu(x):
    pos = tf.nn.relu(x)
    neg = (x - abs(x)) * 0.5
    return pos + (tf.exp(neg) - 1.)
act = elu

sess = tf.Session()
def init_weights(shape, std=None):
    if std is None:
        std = np.sqrt(1. / shape[0])
    return tf.Variable(tf.random_normal(shape, stddev=std))

def init_weights_zero(shape):
    return tf.Variable(np.zeros(shape, dtype='float32'))

learning_rate = 0.0005
nb_iterations = 500
batch_size = 128
nb_outputs = 2
train_losses = []

def model(X, w1, w2, w3, b1, b2, b3):
    h = act(tf.matmul(X, w1) + b1)
    h = tf.nn.dropout(h, 0.5)
    h = act(tf.matmul(h, w2) + b2)
    h = tf.nn.dropout(h, 0.5)
    return tf.matmul(h, w3) + b3

class Classifier(BaseEstimator):
    
    def __init__(self):
        pass
    def build_model(self, nb_features, nb_outputs):
        self.X = tf.placeholder("float", [None, nb_features])
        self.Y = tf.placeholder("float", [None, nb_outputs])
        h1 = 200
        h2 = 200
        w1 = init_weights([nb_features, h1])
        w2 = init_weights([h1, h2])
        w3 = init_weights([h2, nb_outputs])
        b1 = init_weights_zero([h1])
        b2 = init_weights_zero([h2])
        b3 = init_weights_zero([nb_outputs])
        self.Y_pred = model(self.X, w1, w2, w3, b1, b2, b3)
        
        self.cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(self.Y_pred, self.Y))
        self.train_op = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
        self.predict_proba_op =  self.Y_pred
        self.predict_op = tf.argmax(self.Y_pred, 1)
    
    def preprocess(self, X):
        return X - self.mean
    
    def fit(self, X, Y):
        #X, Y = X[0:1000], Y[0:1000]
        
        self.mean = X.mean(axis=0)
        X = self.preprocess(X)
        
        Y = np.vstack((1 - Y, Y)).T
        
        Y = Y.astype(np.float32)
        
        self.build_model(X.shape[1], nb_outputs)
        with sess.as_default():
            tf.initialize_all_variables().run()
            for i in range(nb_iterations):
                for start, end in zip(range(0, len(X), batch_size), range(batch_size, len(X), batch_size)):
                    sess.run(self.train_op, feed_dict={self.X: X[start:end], self.Y: Y[start:end]})
                lossval = sess.run(self.cost, feed_dict={self.X: X, self.Y: Y})
                acc = (sess.run(self.predict_op, feed_dict={self.X: X}) == Y.argmax(axis=1)).mean()
                print('Iteration {}, Train loss : {}, Train acc : {}'.format(i, lossval, acc))
                train_losses.append(acc)

    def predict(self, X):
        X = self.preprocess(X)
        with sess.as_default():
            y_pred = sess.run(self.predict_op, feed_dict={self.X: X})
            return y_pred
    
    def predict_proba(self, X):
        X = self.preprocess(X)
        with sess.as_default():
            y_proba_pred = sess.run(self.predict_proba_op, feed_dict={self.X: X})
            return y_proba_pred

# %% [markdown]
# ## Unit testing
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. For this we provide a unit test. Place the python files <code>classifier.py</code> and <code>user_test_submission.py</code></a> in a directory, set the paths to the data files in <code>user_test_submission.py</code>, and run
#
# <code>python user_test_submission.py</code>
#
# If it runs and prints
# <code>
# Reading file ...
# Training ...
# \-------------------------------------------------------------
# accuracy =  [some_number_between_0_and_1]
# ROC AUC =  [some_number_between_0_and_1]
# \-------------------------------------------------------------
# accuracy =  [some_number_between_0_and_1]
# ROC AUC =  [some_number_between_0_and_1]
# </code>
# you can submit the code.

# %%
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, roc_auc_score 

X = X_df
y = Y_df.values.ravel()

skf = StratifiedShuffleSplit(y, n_iter=3, test_size=0.5, random_state=57)
print("Training ...")
for valid_train_is, valid_test_is in skf:
    print('-------------------------------------------------------------')

    X_valid_train = X.ix[valid_train_is] #[X[i] for i in valid_train_is]
    y_valid_train = y[valid_train_is]
    X_valid_test = X.ix[valid_test_is] #[X[i] for i in valid_test_is]
    y_valid_test = y[valid_test_is]
    
    clf = Classifier()
    clf.fit(X_valid_train.values, y_valid_train)
    y_valid_pred = clf.predict(X_valid_test.values)
    print('accuracy = ', accuracy_score(y_valid_test, y_valid_pred))
    print('ROC AUC = ', roc_auc_score(y_valid_test, y_valid_pred))
    break
# Out:
# Training ...
# -------------------------------------------------------------
# Iteration 0, Train loss : 1.45513057709, Train acc : 0.5228
# Iteration 1, Train loss : 0.78172236681, Train acc : 0.52086
# Iteration 2, Train loss : 0.722003340721, Train acc : 0.52628
# Iteration 3, Train loss : 0.69807690382, Train acc : 0.53264
# Iteration 4, Train loss : 0.690817952156, Train acc : 0.53384
# Iteration 5, Train loss : 0.692279934883, Train acc : 0.53774
# Iteration 6, Train loss : 0.682205915451, Train acc : 0.54224
# Iteration 7, Train loss : 0.677562654018, Train acc : 0.5478
# Iteration 8, Train loss : 0.67541795969, Train acc : 0.54868
# Iteration 9, Train loss : 0.675900101662, Train acc : 0.54522
# Iteration 10, Train loss : 0.674718260765, Train acc : 0.54856
# Iteration 11, Train loss : 0.672539293766, Train acc : 0.55762
# Iteration 12, Train loss : 0.670721113682, Train acc : 0.55306
# Iteration 13, Train loss : 0.671969532967, Train acc : 0.55634
# Iteration 14, Train loss : 0.669706404209, Train acc : 0.55102
# Iteration 15, Train loss : 0.671206235886, Train acc : 0.55784
# Iteration 16, Train loss : 0.670889437199, Train acc : 0.55738
# Iteration 17, Train loss : 0.668455481529, Train acc : 0.56078
# Iteration 18, Train loss : 0.670263588428, Train acc : 0.5567
# Iteration 19, Train loss : 0.668912172318, Train acc : 0.55702
# Iteration 20, Train loss : 0.668755948544, Train acc : 0.55354
# Iteration 21, Train loss : 0.668993294239, Train acc : 0.55164
# Iteration 22, Train loss : 0.668284714222, Train acc : 0.5565
# Iteration 23, Train loss : 0.669207811356, Train acc : 0.55222
# Iteration 24, Train loss : 0.669713139534, Train acc : 0.55438
# Iteration 25, Train loss : 0.667851150036, Train acc : 0.55308
# Iteration 26, Train loss : 0.667985796928, Train acc : 0.5545
# Iteration 27, Train loss : 0.667811870575, Train acc : 0.55238
# Iteration 28, Train loss : 0.667634546757, Train acc : 0.55282
# Iteration 29, Train loss : 0.666520178318, Train acc : 0.55196
# Iteration 30, Train loss : 0.666259467602, Train acc : 0.5547
# Iteration 31, Train loss : 0.665683448315, Train acc : 0.56042
# Iteration 32, Train loss : 0.666747629642, Train acc : 0.55588
# Iteration 33, Train loss : 0.666367352009, Train acc : 0.5586
# Iteration 34, Train loss : 0.665843904018, Train acc : 0.55696
# Iteration 35, Train loss : 0.667087256908, Train acc : 0.55954
# Iteration 36, Train loss : 0.665892183781, Train acc : 0.55974
# Iteration 37, Train loss : 0.665189445019, Train acc : 0.55664
# Iteration 38, Train loss : 0.66476804018, Train acc : 0.55674
# Iteration 39, Train loss : 0.664193928242, Train acc : 0.5565
# Iteration 40, Train loss : 0.664894521236, Train acc : 0.55352
# Iteration 41, Train loss : 0.665197253227, Train acc : 0.55264
# Iteration 42, Train loss : 0.664618968964, Train acc : 0.55992
# Iteration 43, Train loss : 0.664343297482, Train acc : 0.55858
# Iteration 44, Train loss : 0.663952589035, Train acc : 0.5584
# Iteration 45, Train loss : 0.663384854794, Train acc : 0.56352
# Iteration 46, Train loss : 0.664189696312, Train acc : 0.5614
# Iteration 47, Train loss : 0.663325309753, Train acc : 0.55856
# Iteration 48, Train loss : 0.66232407093, Train acc : 0.56056
# Iteration 49, Train loss : 0.662266731262, Train acc : 0.56194
# Iteration 50, Train loss : 0.663477599621, Train acc : 0.5642
# Iteration 51, Train loss : 0.662328600883, Train acc : 0.5608
# Iteration 52, Train loss : 0.663061380386, Train acc : 0.56246
# Iteration 53, Train loss : 0.662147045135, Train acc : 0.566
# Iteration 54, Train loss : 0.662253379822, Train acc : 0.56368
# Iteration 55, Train loss : 0.663270533085, Train acc : 0.55844
# Iteration 56, Train loss : 0.662342965603, Train acc : 0.565
# Iteration 57, Train loss : 0.662462472916, Train acc : 0.562
# Iteration 58, Train loss : 0.661626577377, Train acc : 0.55964
# Iteration 59, Train loss : 0.66185426712, Train acc : 0.56352
# Iteration 60, Train loss : 0.661193430424, Train acc : 0.5628
# Iteration 61, Train loss : 0.661024987698, Train acc : 0.56326
# Iteration 62, Train loss : 0.660756468773, Train acc : 0.56552
# Iteration 63, Train loss : 0.661641538143, Train acc : 0.56138
# Iteration 64, Train loss : 0.660457491875, Train acc : 0.56544
# Iteration 65, Train loss : 0.661493659019, Train acc : 0.56328
# Iteration 66, Train loss : 0.660561084747, Train acc : 0.56324
# Iteration 67, Train loss : 0.66091376543, Train acc : 0.56636
# Iteration 68, Train loss : 0.660712361336, Train acc : 0.561
# Iteration 69, Train loss : 0.659402906895, Train acc : 0.56666
# Iteration 70, Train loss : 0.659855365753, Train acc : 0.56532
# Iteration 71, Train loss : 0.66094994545, Train acc : 0.56438
# Iteration 72, Train loss : 0.659547030926, Train acc : 0.56628
# Iteration 73, Train loss : 0.659597635269, Train acc : 0.5648
# Iteration 74, Train loss : 0.658950328827, Train acc : 0.56478
# Iteration 75, Train loss : 0.659208774567, Train acc : 0.56664
# Iteration 76, Train loss : 0.658493220806, Train acc : 0.56876
# Iteration 77, Train loss : 0.65934920311, Train acc : 0.56884
# Iteration 78, Train loss : 0.660164833069, Train acc : 0.5694
# Iteration 79, Train loss : 0.658569514751, Train acc : 0.56974
# Iteration 80, Train loss : 0.659600317478, Train acc : 0.5696
# Iteration 81, Train loss : 0.65957647562, Train acc : 0.56534
# Iteration 82, Train loss : 0.658992648125, Train acc : 0.56822
# Iteration 83, Train loss : 0.660212814808, Train acc : 0.5671
# Iteration 84, Train loss : 0.658831119537, Train acc : 0.57146
# Iteration 85, Train loss : 0.658596038818, Train acc : 0.56902
# Iteration 86, Train loss : 0.658300936222, Train acc : 0.56702
# Iteration 87, Train loss : 0.657707571983, Train acc : 0.56664
# Iteration 88, Train loss : 0.659257113934, Train acc : 0.56946
# Iteration 89, Train loss : 0.656651258469, Train acc : 0.56934
# Iteration 90, Train loss : 0.658142983913, Train acc : 0.5709
# Iteration 91, Train loss : 0.657290935516, Train acc : 0.5695
# Iteration 92, Train loss : 0.656612336636, Train acc : 0.56862
# Iteration 93, Train loss : 0.655946731567, Train acc : 0.57122
# Iteration 94, Train loss : 0.658366978168, Train acc : 0.5706
# Iteration 95, Train loss : 0.657028436661, Train acc : 0.56614
# Iteration 96, Train loss : 0.657771706581, Train acc : 0.57256
# Iteration 97, Train loss : 0.65670478344, Train acc : 0.5695
# Iteration 98, Train loss : 0.657213509083, Train acc : 0.5694
# Iteration 99, Train loss : 0.658424437046, Train acc : 0.56754
# Iteration 100, Train loss : 0.656586885452, Train acc : 0.57272
# Iteration 101, Train loss : 0.656866788864, Train acc : 0.56822
# Iteration 102, Train loss : 0.656679272652, Train acc : 0.56842
# Iteration 103, Train loss : 0.657319366932, Train acc : 0.5687
# Iteration 104, Train loss : 0.65688842535, Train acc : 0.56978
# Iteration 105, Train loss : 0.657417714596, Train acc : 0.56912
# Iteration 106, Train loss : 0.657448112965, Train acc : 0.57076
# Iteration 107, Train loss : 0.657410860062, Train acc : 0.56804
# Iteration 108, Train loss : 0.657261431217, Train acc : 0.56672
# Iteration 109, Train loss : 0.655433416367, Train acc : 0.57164
# Iteration 110, Train loss : 0.655573129654, Train acc : 0.56986
# Iteration 111, Train loss : 0.655737400055, Train acc : 0.571
# Iteration 112, Train loss : 0.65469533205, Train acc : 0.56766
# Iteration 113, Train loss : 0.65685904026, Train acc : 0.57014
# Iteration 114, Train loss : 0.655126690865, Train acc : 0.5665
# Iteration 115, Train loss : 0.656407058239, Train acc : 0.5701
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-267-cbdc80e08ced> in <module>()
#      17
#      18     clf = Classifier()
# ---> 19     clf.fit(X_valid_train.values, y_valid_train)
#      20     y_valid_pred = clf.predict(X_valid_test.values)
#      21     print('accuracy = ', accuracy_score(y_valid_test, y_valid_pred))
#
# <ipython-input-266-b07a66de051e> in fit(self, X, Y)
#      77             for i in range(nb_iterations):
#      78                 for start, end in zip(range(0, len(X), batch_size), range(batch_size, len(X), batch_size)):
# ---> 79                     sess.run(self.train_op, feed_dict={self.X: X[start:end], self.Y: Y[start:end]})
#      80                 lossval = sess.run(self.cost, feed_dict={self.X: X, self.Y: Y})
#      81                 acc = (sess.run(self.predict_op, feed_dict={self.X: X}) == Y.argmax(axis=1)).mean()
#
# /root/miniconda2/envs/databoard-env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict)
#     343
#     344     # Run request and get response.
# --> 345     results = self._do_run(target_list, unique_fetch_targets, feed_dict_string)
#     346
#     347     # User may have fetched the same tensor multiple times, but we
#
# /root/miniconda2/envs/databoard-env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, target_list, fetch_list, feed_dict)
#     402
#     403       return tf_session.TF_Run(self._session, feed_dict, fetch_list,
# --> 404                                target_list)
#     405
#     406     except tf_session.StatusNotOK as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Variable importances
#
# This will plot the variable importance according to your model.
#
# **Your model may not implement it, this is an example of how to do it with RandomForest**

# %%
plt.figure(figsize=(15, 5))

ordering = np.argsort(clf.clf.feature_importances_)[::-1][:50]

importances = clf.clf.feature_importances_[ordering]
feature_names = X_df.columns[ordering]

x = np.arange(len(feature_names))
plt.bar(x, importances)
plt.xticks(x + 0.5, feature_names, rotation=90, fontsize=15);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-264-de206c9201ce> in <module>()
#       1 plt.figure(figsize=(15, 5))
#       2
# ----> 3 ordering = np.argsort(clf.clf.feature_importances_)[::-1][:50]
#       4
#       5 importances = clf.clf.feature_importances_[ordering]
#
# AttributeError: 'Classifier' object has no attribute 'clf'

# %% [markdown]
# ## Roc curve

# %%
from scipy import interp
from sklearn.metrics import roc_curve , auc
from sklearn.pipeline import make_pipeline

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedShuffleSplit(y, n_iter=3, test_size=0.5, random_state=57)
classifier = Classifier()

mean_tpr = 0.0
mean_fpr = np.linspace(0, 1, 100)
all_tpr = []
X = X_df
y = Y_df.values.ravel()

for i, (train, test) in enumerate(cv):
    probas_ = classifier.fit(X.ix[train], y[train]).predict_proba(X.ix[test])
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
    mean_tpr += interp(mean_fpr, fpr, tpr)
    mean_tpr[0] = 0.0
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))

plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')

mean_tpr /= len(cv)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
plt.plot(mean_fpr, mean_tpr, 'k--',
         label='Mean ROC (area = %0.2f)' % mean_auc, lw=2)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Learning curves

# %%
def plot_learning_score(train_sizes, train_scores, test_scores, score_name='Score'):
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.figure()
    plt.title('Learning curve')
    if score_name != "Time":
        plt.ylim(0, 1)
    plt.xlabel("Training examples")
    plt.ylabel(score_name)

    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training "+score_name)
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation "+score_name)
    plt.legend(loc="best")
    plt.show()

# %% [markdown]
# The next cell may take some time.

# %%
import time
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, roc_auc_score 

sizes = np.linspace(0.1, 1., num=6)
train_accuracy = []
test_accuracy = []
train_auc = []
test_auc = []
train_t = []  # Training time
test_t = []  # Testing time
for size in sizes:
    _train_accuracy = []
    _test_accuracy = []
    _train_auc = []
    _test_auc = []
    _train_t = []  # Training Time
    _test_t = []  # Testing Time
    skf = StratifiedShuffleSplit(y[:int(size*y.shape[0])], n_iter=3, test_size=0.5, random_state=57)
    for valid_train_is, valid_test_is in skf:
        X_valid_train = X.ix[valid_train_is] #[X[i] for i in valid_train_is]
        y_valid_train = y[valid_train_is]
        X_valid_test = X.ix[valid_test_is] #[X[i] for i in valid_test_is]
        y_valid_test = y[valid_test_is]

        clf = Classifier()
        
        start = time.time()
        clf.fit(X_valid_train, y_valid_train)
        _train_t.append(time.time()-start)
        
        start = time.time()
        y_valid_pred = clf.predict(X_valid_train)
        half_time = time.time()-start
        _train_accuracy.append(accuracy_score(y_valid_pred, y_valid_train))
        _train_auc.append(roc_auc_score(y_valid_pred, y_valid_train))
        
        start = time.time()
        y_valid_pred = clf.predict(X_valid_test)
        _test_t.append(time.time()-start+half_time)
        _test_accuracy.append(accuracy_score(y_valid_pred, y_valid_test))
        _test_auc.append(roc_auc_score(y_valid_pred, y_valid_test))
    train_accuracy.append(_train_accuracy)
    test_accuracy.append(_test_accuracy)
    train_auc.append(_train_auc)
    test_auc.append(_test_auc)
    train_t.append(_train_t)
    test_t.append(_test_t)
    
train_accuracy = np.array(train_accuracy)
test_accuracy = np.array(test_accuracy)
train_auc = np.array(train_auc)
test_auc = np.array(test_auc)
train_t = np.array(train_t)
test_t = np.array(test_t)

# %%
plot_learning_score(sizes, train_accuracy, test_accuracy, score_name='Accuracy')
plot_learning_score(sizes, train_auc, test_auc, score_name='ROC AUC')
plot_learning_score(sizes, train_t, test_t, score_name='Time')
# Out:
# /Users/kegl/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
