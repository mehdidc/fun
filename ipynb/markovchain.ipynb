# %%
from collections import defaultdict
import numpy as np

# %%
names = open('male.txt').readlines()[6:]
names = map(lambda name:name[0:-1], names)
names = map(lambda name:name.lower(), names)

# %%
def build_model(data, deg=1):
    freq = defaultdict(lambda:defaultdict(float))
    for element in data:
        element = "^" * deg + element + "$"
        for i in range(deg, len(element)):
            freq[element[i - deg:i]][element[i]] += 1
    sum_freqs = {}
    for k, v in freq.items():
        sum_freqs[k] = sum(nb for nb in v.values())
        for kprev in freq[k].keys():
            freq[k][kprev] = float(freq[k][kprev]) / sum_freqs[k]
    return freq

# %%
max_deg = 3
models = []
for deg in range(max_deg, 0, -1):
    print(deg)
    models.append((build_model(names, deg=deg), deg))
# Out:
# 3
# 2
# 1

# %%
def gen(models, max_size=300, temp=1):    
    maxdeg = max(d for m, d in models)
    s = "^" * maxdeg
    for i in range(maxdeg, maxdeg + max_size):
        pr = None
        for model, deg in models:
            prev = s[i - deg:i]
            if prev in model:
                pr = model
                break
        assert pr is not None
        chars = pr[prev].keys()
        probas = np.array(pr[prev].values())
        if temp != 1:
            probas = softmax((probas * temp)[None, :])[0]
        char_idx = np.random.multinomial(1, probas).argmax()
        char = chars[char_idx]
        s += char
        if char == "$":
            break
    return s

def softmax(w):
    maxes = np.amax(w, axis=1)
    maxes = maxes.reshape(maxes.shape[0], 1)
    e = np.exp(w - maxes)
    dist = e / np.sum(e, axis=1, keepdims=True)
    return dist

# %%
fake_names = [gen(models, temp=0.).replace('^', '').replace('$', '').capitalize() for i in range(1000)]

# %%
nb_from_training_data = sum(1 if name.lower() in names else 0 for name in fake_names)
print('Perc. generated exactly like training data : {}%'.format(100. * nb_from_training_data/len(fake_names)))
print('Perc. generated which are original : {}%'.format(100. - 100. * nb_from_training_data/len(fake_names)))
# Out:
# Perc. generated exactly like training data : 25.5%
# Perc. generated which are original : 74.5%

# %%
fake_names = [name for name in fake_names if name.lower() not in names]

# %%
for n in fake_names:
    print(n)
# Out:
# Guth
# Zipp
# Ibrahimond
# Xavie
# Kasparrotty
# Vaily
# Faird
# Wojcie
# Justas
# Acey
# Obally
# Wyatthachad
# Gabritz
# Hogarol
# Aberoyal
# Yaco
# Bjorde
# Dmith
# Xymen
# Voltaillmarvy
# Yehu
# Ritty
# Ayle
# Feliuseinhols
# Urstaveryl
# Xavinsloan
# Gonzalessee
# Ton
# Crawleroy
# Bhardonas
# Lutheustirlie
# Paigeriggy
# Verlylen
# Fedee
# Owe
# Fordanos
# Sylvanitos
# Felig
# Hanfie
# Udalthenroy
# Mylent
# Lleryleroyaleslie
# Grahamlincent
# Ven
# Xevel
# Felig
# Yehu
# Micho
# Fin
# Baxtere
# Voltait
# Omartissy
# Yaak
# Zer
# Pascary
# Lias
# Irvis
# Montaguel
# Cardney
# Fyodoor
# Esarges
# Jimmith
# Zel
# Xim
# Ahamir
# Wainnielson
# Mili
# Quentis
# Hodgerardecai
# Swelch
# Cesau
# Istacy
# Kevancary
# Kley
# Irwinfredougie
# Fletchermienny
# Natias
# Ajaimunrodysselbie
# Inifacey
# Valee
# Nunzier
# Ximervey
# Amber
# Haimeo
# Omarmo
# Jonnormaddy
# Zecht
# Rus
# Hasturnar
# Glenat
# Trumand
# Voltair
# Stillam
# Uptonis
# Fyodolfy
# Halvis
# Juergilldo
# Raud
# Muhamlinglen
# Stineronat
# Georgan
# Bjorny
# Napostead
# Geanthonstol
# Kraimunrod
# Byrong
# Gly
# Ques
# Gunne
# Vergustephraynan
# Doro
# Gerolaf
# Abez
# Xavis
# Ques
# Kiptonnolds
# Owendaneetf
# Eth
# Que
# Avis
# Fowlero
# Xeven
# Maynar
# Tilldo
# Zoll
# Wellus
# Smitrius
# Towniel
# Dorinigelbie
# Gory
# Dus
# Mon
# Uricareynan
# Yaakob
# Rhet
# Misco
# Voltaite
# Walkermonrade
# Wadean-chrison
# Amemnon
# Immanus
# Ebedediegfriel
# Rudyarde
# Quiglyn
# Bjordie
# Zippie
# Oberculis
# Luthro
# Odiego
# Elvyn
# Flornton
# Cyrusseinz
# Tearnerdy
# Verlos
# Ebenn
# Rutteodoro
# Logaronn
# Vertimon
# Damsay
# Krise
# Pedrosi
# Yvestledgarv
# Thieu
# Zippierson
# Yigallyn
# Nediegfritzgerhar
# Silvestevindy
# Dabnerd
# Yaco
# Ruperrmail
# Izaakob
# Fer
# Fyodoor
# Heil
# Zorr
# Kerreynorbes
# Schana
# Xymenaldus
# Fowlanney
# Xavis
# Ques
# Umberom
# Whee
# Wrigglyndhamie
# Yurienniell
# Kraiger
# Jean-chrielly
# Que
# Earardt
# Hezer
# Uptonn
# Wortyn
# Nicoln
# Ryancroft
# Jethery
# Mish
# Wen
# John-daveltonnolairfax
# Hadenestbrodelm
# Ques
# Zippe
# Timeo
# Gusonn
# Byrams
# Oswelby
# Gusto
# Apolemarlo
# Vladams
# Xavilhel
# Wordo
# Platony
# Sampsonnorm
# Whittiano
# Hirschard
# Nunzie
# Kos
# Ques
# Trenatorry
# Zipp
# Ques
# Ewangie
# Quillyn
# Grahul
# Quenten
# Rickarin
# Frasunner
# Dus
# Engelias
# Zachield
# Zippietey
# Anandory
# Inique
# Teadenn
# Agangsly
# Phinealson
# Yacobbie
# Jimminealle
# Criss
# Hymien
# Zolloyd
# Yardt
# Magnacey
# Adgeram
# Naton
# Hudsone
# Quentinerdy
# Ashishna
# Piggly
# Lessanfieldemarshea
# Yigaleif
# Larey
# Xim
# Quiggs
# Florenzio
# Clivie
# Vladenitake
# Est
# Kurtney
# Urstearly
# Jimbald
# Kley
# Swell
# Loth
# Quillmotheus
# Lawerem
# Fedekiah
# Ashishea
# Higgs
# Thenderbinkley
# Yulesley
# Skele
# Veralphusein
# Triss
# Ques
# Wiatty
# Ichy
# Palmershallias
# Dexternd
# Pauld
# Coopertranvil
# Ibrady
# Lor
# Omandikelerman
# Yigaleif
# Kurtney
# Tirrelless
# Sring
# Dylanniell
# Zollo
# Fult
# Wan
# Tearlanne
# Quinleigh
# Mikelvyn
# Marmitt
# Xeve
# Etie
# Que
# Feli
# Abbertolliony
# Tedickardt
# Vijah
# Emaise
# Tearcus
# Ibradfore
# Gavriet
# Brahamnett
# Octavus
# Torpe
# Uptonio
# Ephenis
# Irvier
# Wey
# Owelsendra
# Newtonen
# Grises
# Platonny
# Dilly
# Irvie
# Sanse
# Chim
# Dor
# Chieu
# Iano
# Quiller
# Quigmarclarste
# Quilldo
# Obercy
# Quillarsiff
# Efry
# Ismaison
# Udalthedriques
# Obary
# Yehuditya
# Moor
# Penry
# Turgiovanueley
# Plator
# Xymenestephen
# Ehudsonellyn
# Law
# Eld
# Ryancey
# Reuvenkat
# Vladam
# Blay
# Gailiellus
# Rittakerryl
# Channey
# Joachaughn
# Fin
# Avel
# Vainer
# Dietta
# Osmondsayre
# Efry
# Eastas
# Wiattie
# Eus
# Quilldo
# Dwarter
# Fyodolphusainerdin
# Oria
# Ismailippy
# Wan
# Xavindsey
# Xavidson
# Eph
# Curtien
# Omason
# Tram
# Quinleightoldo
# Zippertracey
# Tie
# Ximir
# Riple
# Hebaronny
# Ezekiah
# Kylen
# Zolloyd
# Ques
# Jimmitta
# Kylardnee
# Yvestle
# Reigh
# Valeed
# Platolds
# Lexei
# Uptony
# Hurcelothebenger
# Gleben
# Vladen
# Ibradclid
# Bogdantoineastanneddius
# Fyodolph
# Ichimontgomense
# Quincus
# Guin
# Olino
# Kalvanos
# Wrightolom
# Oss
# Xim
# Eus
# Sringmarlonnibal
# Klaury
# Immothatchadd
# Glennis
# Townserge
# Wittias
# Ague
# Irwinni
# Wrigo
# Egbercio
# Xime
# Doylen
# Irvile
# Gly
# Higgs
# Yehu
# Yehu
# Nah
# Tibolds
# Que
# Fedekiah
# Clemy
# Remiah
# Ursone
# Flipe
# Zippiet
# Amber
# Tho
# Cescoe
# Neasty
# Nial
# Ude
# Omarcht
# Umberharilu
# Que
# Ivanuragnum
# Wrigh
# Kylaneel
# Vladam
# Lio
# Rainny
# Valejan
# Eld
# Iramischucky
# Mustus
# Wins
# Marchy
# Umber
# Muham
# Ivanus
# Whita
# Nunzie
# Que
# Emminerd
# Amarmin
# Bish
# Humphremy
# Octavus
# Ulysseus
# Yvesternorbie
# Etie
# Elvyn
# Llo
# Wrigo
# Anat
# Webenso
# Waneel
# Evel
# Wojcien
# Zacken
# Frenault
# Jimmonen
# Fultonio
# Whitakeenault
# Colm
# Heywooch
# Clyden
# Uptony
# Zorry
# Vlade
# Lor
# Pensendru
# Liot
# Juanilek
# Que
# Brey
# Hogard
# Napoleg
# Dylarkus
# Bjor
# Juli
# Gleb
# Gly
# Yal
# Umberhariot
# Ado
# Lian
# Umberculestoph
# Tudore
# Quillynn
# Caid
# Agamelvio
# Dudleif
# Weide
# Wyliercho
# Moores
# Cescot
# Zarylenar
# Owenderkiele
# Yancan
# Adge
# Que
# Yulesley
# Nes
# Guson
# Sta
# Higgy
# Udalley
# Zalejandy
# Munroededith
# Niley
# Uptony
# Teodoore
# Zederyl
# Zipperret
# Yehudsonen
# Yurish
# Eridas
# Smitchillarstevinslowend
# Gentoine
# Nolds
# Byramsayes
# Aylindhamus
# Dwardiego
# Clid
# Howarin
# Rille
# Philionidas
# Kylangustig
# Romy
# Hilburl
# Blayton
# Ximir
# Amorlandley
# Tade
# Bharedmon
# Swendannander
# Emersonerdinal
# Quinandy
# Meyersh
# Yardie
# Arediah
# Xymenso
# Trumannan
# Vladamostos
# Prin
# Gearlos
# Xymenadolpho
# Obe
# Fedethrem
# Denez
# Cescoe
# Mus
# Siff
# Quiggie
# Vincentice
# Veryl
# Creinz
# Xymendanny
# Dmitry
# Dmitry
# Felippe
# Ear
# Mustuardnee
# Vaclai
# Prenediego
# Bharardt
# Zipperdy
# Purchip
# Dalemonen
# Laumeetf
# Valdrias
# Xymens
# Curtiebourtien
# Taylmers
# Quincasparnardlery
# Ortolomerwindy
# Mustanly
# Curtimeo
# Rhet
# Busty
# Zipper
# Gly
# Gonzie
# Fraziz
# Giderscheillivanos
# Cyrilu
# Zel
# Viler
# Bharwinstacy
# Earnon
# Heberkiellwood
# Juergusonnolaird
# Apolemmottias
# Fonzalenado
# Ripletta
# Amadean
# Meyeredros
# Xyment
# Ques
# Reynandi
# Vladenn
# Que
# Fult
# Henic
# Yvestledgarv
# Zacki
# Uristeban
# Eth
# Zipperdiegory
# Flynd
# Quilley
# Dre
# Frazio
# Bonid
# Wyatanwooch
# Yigalec
# Glyn
# Higgly
# Kevi
# Eduanilsonn
# Ryana
# Xavi
# Ximeryler
# Fidellwoodrik
# Jimbaltherdy
# Apoleg
# Woldo
# Darrylesliercy
# Ximir
# Gonzie
# Ritchilio
# Iraul
# Iram
# Svenkat
# Victore
# Hus
# Clivenkat
# Timotty
# Kylero
# Rawforticentis
# Vaugie
# Byronatallaus
# Blars
# Nedy
# Xeve
# Guidoro
# Umbertolomeniche
# Giordy
# Wyndharvilli
# Immottias
# Nestleigh
# Clydenishalejano
# Wyntonysus
# Jessanfie
# Zippiett
# Tudorios
# Fridas
# Mikhaineron
# Voltailermy
# Wen
# Byronar
# Duff
# Aguidorey
# Quiggy
# Biffarlien
# Gernstailio
# Domine
# Xavilhel
# Barby
# Owendi
# Devie
# Zar
# Udallipe
# Umberoyce
# Piggly
# Umbertram
# Hilierrong
# Purcht
# Pietey
# Kevierronser
# Omarchil
# Felihu
# Beron
# Din
# Earlyle
# Dineallausty
# Jephuss
# Prenan
# Kurtney
# Pincoishnat
# Jothaxteretchail
# Tramid
# Rhet
# Fedethatchenico
# Uptonifacey
# Ulish
# Ernon
# Yehu
# Tucke
# Zel
# Ques
# Yalemy
# Travinnislaweretchiboldonnon
# Krison
# Yal
# Nah
# Rens
# Haile
# Zerkleed
# Uliotty
# Flemy
# Zippiersh
# Zoll
# Hil
# Wylino
# Robe
# Fiderjit
# Bal
# Dylarandrigh
# Fideo
# Teditya
# Iancey
# Rhetta
# Zorry
# Wilfrem
# Quin
# Ferndi
# Alsonelisheffith
# Ibraharwellwoodmanfredrikki
# Grisy
