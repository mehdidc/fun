# %%
from collections import defaultdict
import numpy as np

# %%
names = open('male.txt').readlines()[6:]
names = map(lambda name:name[0:-1], names)
names = map(lambda name:name.lower(), names)

# %%
def build_model(data, deg=1):
    freq = defaultdict(lambda:defaultdict(float))
    for element in data:
        element = "^" * deg + element + "$"
        for i in range(deg, len(element)):
            freq[element[i - deg:i]][element[i]] += 1
    sum_freqs = {}
    for k, v in freq.items():
        sum_freqs[k] = sum(nb for nb in v.values())
        for kprev in freq[k].keys():
            freq[k][kprev] = float(freq[k][kprev]) / sum_freqs[k]
    return freq

# %%
max_deg = 3
models = []
for deg in range(max_deg, 0, -1):
    print(deg)
    models.append((build_model(names, deg=deg), deg))
# Out:
# 3
# 2
# 1

# %%
def gen(models, max_size=300, temp=1):    
    maxdeg = max(d for m, d in models)
    s = "^" * maxdeg
    for i in range(maxdeg, maxdeg + max_size):
        pr = None
        for model, deg in models:
            prev = s[i - deg:i]
            if prev in model:
                pr = model
                break
        assert pr is not None
        chars = pr[prev].keys()
        probas = np.array(pr[prev].values())
        if temp != 1:
            probas = softmax((probas * temp)[None, :])[0]
        char_idx = np.random.multinomial(1, probas).argmax()
        char = chars[char_idx]
        s += char
        if char == "$":
            break
    return s

def softmax(w):
    maxes = np.amax(w, axis=1)
    maxes = maxes.reshape(maxes.shape[0], 1)
    e = np.exp(w - maxes)
    dist = e / np.sum(e, axis=1, keepdims=True)
    return dist

# %%
fake_names = [gen(models, temp=0.).replace('^', '').replace('$', '').capitalize() for i in range(1000)]

# %%
nb_from_training_data = sum(1 if name.lower() in names else 0 for name in fake_names)
print('Perc. generated exactly like training data : {}%'.format(100. * nb_from_training_data/len(fake_names)))
print('Perc. generated which are original : {}%'.format(100. - 100. * nb_from_training_data/len(fake_names)))
# Out:
# Perc. generated exactly like training data : 24.4%
# Perc. generated which are original : 75.6%

# %%
fake_names = [name for name in fake_names if name.lower() not in names]

# %%
for n in fake_names:
    print(n)
# Out:
# Thewer
# Ximil
# Wheelero
# Enroedediah
# Egberk
# Kaneet
# Thingtonid
# Hudsonn
# Menerom
# Nator
# Eugentle
# Aamid
# Gunnese
# Umber
# Urisonn
# Tiebourtollip
# Taylann
# Olai
# Ayloriot
# Ursone
# Blaynolds
# Maddeus
# Mery
# Irwinifie
# Terl
# Barby
# Dwig
# Cyrillmarlinson
# Etieboldonnie
# Zipp
# Glenticentino
# Zel
# Rus
# Lan
# Higglynn
# Xavide
# Parrney
# Uptonny
# Fridas
# Verguson
# Vain
# Tyn
# Llemostebanuele
# Eret
# Rhettakermy
# Llonnorby
# Trumandall
# Vaugh
# Pauld
# Whee
# Byronah
# Zalmars
# Ich
# Lemien
# Obarbabasilas
# Crein
# Octav
# Templey
# Elt
# Villdo
# Stacey
# Wrigh
# Umberoyaleslim
# Emarwinstacy
# Vitered
# Heillus
# Wordanils
# Zerkiellivaldriel
# Udah
# Hilishop
# Ibramsonelippe
# Oman
# Xime
# Svenkat
# Yaakob
# Etheodooreynar
# Migue
# Ivaldis
# Liot
# Estleryl
# Cosmundrzej
# Nigoricio
# Gamey
# Phingmarvileslim
# Din
# Trumanie
# Blary
# Pear
# Hyatalemonroe
# Ques
# Vert
# Tandy
# Zorre
# Gome
# Egberticentle
# Sherby
# Jothatchansendre
# Flinos
# Yacomo
# Wrigh
# Tirlin
# Ephenrodneetf
# Cratias
# Framemnon
# Dylandy
# Earnield
# Smit
# Zarong
# Bjorntoine
# Ashlomeir
# Teredouggie
# Have
# Acey
# Erlyler
# Ewangeli
# Rhettake
# Edmannan
# Fyodoro
# Ques
# Pietey
# Welsen
# Ebedediah
# Spar
# Tiebour
# Zorryl
# Yuless
# Thing
# Rag
# Zechailo
# Boni
# Zippie
# Thuss
# Blai
# Que
# Niel
# Shurl
# Dwaiterek
# Weidas
# Ewariswort
# Sargen
# Ulriccarlin
# Efraziz
# Deme
# Nato
# Xavis
# Xenoch
# Lonnoller
# Yaak
# Dwaynordy
# Teodooreynorwoodyssee
# Drakefieldo
# Troscalvardockerry
# Brosius
# Yaak
# Fyodoore
# Ivanny
# Bobbey
# Philberharr
# Ude
# Dall
# Fonzo
# Mickolag
# Umberce
# Vass
# Tearans
# Agan
# Guinal
# Zerkellwooch
# Lyndo
# Sylvailessil
# Voltailis
# Xavidsonny
# Xime
# Zalonnold
# Oswelsen
# Hold
# Dylanny
# Jimbal
# Rhet
# Heltonysus
# Nahumberton
# Hilbur
# Ozziercy
# Platol
# Yulessiegorinaudi
# Socrat
# Que
# Vas
# Platolo
# Ban
# Piot
# Deante
# Philishannon
# Radfortyn
# Micarle
# Ashishnatinos
# Goodmani
# Sumneromei
# Igglynn
# Vladeas
# Pars
# Phington
# Felig
# Dillmanney
# Eastoph
# Shee
# Otty
# Wrigginandfordinaldis
# Mish
# Clivanus
# Platorpe
# Portinkleed
# Voltair
# Dwickey
# Goobernaby
# Sydnee
# Zorrek
# Yankley
# Vailermith
# Avis
# Sutto
# Raime
# Giliot
# Quiggy
# Vladaird
# Seamuel
# Zippie
# Uptoniusepparshe
# Quentere
# Tanito
# Zachaillmotto
# Fonzo
# Voltaite
# Nunzie
# Rutleed
# Nigordy
# Peternabastirlingtone
# Fedethrupertimmittakeefe
# Meiers
# Batho
# Hudiegfridan
# Collynn
# Llel
# Curtin
# Lionid
# Ody
# Ewarie
# Godarill
# Mey
# Yuriancasergiordie
# Wold
# Filmery
# Wrigglynn
# Shimotty
# Consiegfriettakeemain
# Xavis
# Ximir
# Tillonnie
# Ashtold
# Oberney
# Hunterley
# Nah
# Lincolless
# Urbaily
# Creinz
# Kurtonelis
# Yurist
# Jimbal
# Svenkat
# Ree
# Vass
# Kylerylery
# Eucliftonnor
# Tyless
# Apoleonharvis
# Yules
# Vainwrightollaude
# Jai
# Egbercio
# Colberke
# Emanforty
# Svenkat
# Leryle
# Ulbern
# Muhammet
# Hender
# Wen
# Dugang
# Kos
# Artonnin
# Nie
# Fyodory
# Omaisonnie
# Naten
# Guinleigh
# Kriswolfie
# Higgy
# Nunziercelotheldon
# Iano
# Quigmarwinford
# Viterlane
# Ximill
# Prichimonen
# Wheem
# Octavoud
# Rileks
# Orr
# Ryantinos
# Que
# Xim
# Xenoch
# Tile
# Mas
# Glyndo
# Kraimunroededictorri
# Quillus
# Kurtinod
# Aamisch
# Liot
# Leed
# Osgoodmanileromy
# Oteser
# Gira
# Domeonhary
# Lor
# Platolly
# Yehudson
# Dysonnordine
# Mendrzej
# Igglynn
# Wrigglyn
# Emerry
# Sutterrey
# Clary
# Home
# Enos
# Osmonradlaird
# Platolo
# Ursonnollo
# Agusonnordocheinz
# Tyle
# Fedediegfrielsonnold
# Xaviner
# Myronningamadeust
# Zipp
# Udas
# Ibranz
# Zalmothah
# Ques
# Naposten
# Thussee
# Oman
# Duffith
# Hus
# Toment
# Lorey
# Zollestler
# Efrastuardneetf
# Dextern
# Orace
# Danita
# Wylienne
# Set
# Uptone
# Tonni
# Xymenaulo
# Eraseymoud
# Ryanthon
# Xavid
# Yehu
# Hillin
# Xavius
# Ques
# Juanils
# Blararden
# Fin
# Yacobber
# Sollasdairfacey
# Piggs
# Hymanuel
# Felicenter
# Uptone
# Arlang
# Zolli
# Rit
# Ezechtolo
# Whee
# Zer
# Fedekie
# Xymens
# Nahumphreynardleigh
# Apolemy
# Jasparsonnon
# Napolemminerd
# Hartiebourke
# Zorr
# Murdo
# Zorr
# Zaloysiusein
# Graden
# Meiershanitakeemo
# Agustew
# Baldoni
# Wendie
# Sutteo
# Xim
# Tiboldon
# Fyodolpherforres
# Ikellus
# Egber
# Yuric
# Mus
# Heltonen
# Azio
# Ismaise
# Acey
# Shorny
# Ryanciscoe
# Moorendike
# Udal
# Jenneddiuseppardiegfrid
# Thamner
# Octave
# Faird
# Hazelio
# Ore
# Higgis
# Clind
# Ryancan
# Dylarsifacey
# Que
# Aylo
# Gallynn
# Fidered
# Ginaudi
# Otty
# Dmit
# Kars
# Apostorrardneet
# Nah
# Smitchiboldo
# Washtonysus
# Kyless
# Cliftony
# Owe
# Tainwrigory
# Voltaillmon
# Filionislawrencio
# Cai
# Lucaser
# Ximitch
# Bjorge
# Loveltonny
# Luthedrowlann
# Kurticentiss
# Yehudigerellive
# Zoll
# Nevind
# Voltaite
# Umberolf
# Devie
# Nah
# Dewelberkleed
# Swells
# Romas
# Owelson
# Whitmann
# Jodysoneronnis
# Milie
# Quentoine
# Ulricio
# Ryank
# Vach
# Zolloysiusephus
# Irvis
# Quenticenterey
# Urbaird
# Penry
# Xeve
# Dimilldonatoll
# Gomendraimunmro
# Talex
# Welbartainer
# Nunzie
# Vladenes
# Smitchabod
# Weidarias
# Batro
# Travi
# Eldemo
# Rinky
# Wen
# Llel
# Mann
# Wrigordonardiego
# Ques
# Wen
# Wortice
# Kasperdiegfrid
# Mosef
# Wavergi
# Voltainerolangie
# Smit
# Bjory
# Ven
# Nunzierraynerd
# Amon
# Wyndolpherd
# Bel
# Vladamonen
# Johamir
# Javil
# Urisy
# Moor
# Leed
# Icholds
# Octavidson
# Tobertimeromanforto
# Sutto
# Kurto
# Tudolfgangemarkosteffe
# Lazaredfortie
# Fide
# Laynoldo
# Ewareynolane
# Binsomerwintonny
# Hirschare
# Horvaldwindy
# Dwint
# Hen
# Beal
# Xavi
# Xim
# Konso
# Weylinus
# Eucliffarlan
# Quillmott
# Has
# Ques
# Yehu
# Westbronahul
# Kylandi
# Zedeth
# Mikelwinny
# Huntleif
# Nolaneel
# Fostophyllus
# Apostoferndi
# Sumnettakermon
# Xymenitolliverlyleronen
# Jensendi
# Wordoch
# Hurce
# Easty
# Meadeus
# Kaison
# Ques
# Zan
# Justu
# Dmitcheinrikki
# Yvest
# Xavingamarmstron
# Llen
# Sullenadoro
# Chiboldonah
# Giffith
# Dmith
# Omainwrigo
# Ximitriusephuss
# Jabela
# Yehu
# Maxfie
# Iancroft
# Meyeremie
# Lairfacey
# Gusonninoe
# Que
# Winfrenedy
# Gia
# Pauld
# Uried
# Hobardt
# Wen
# Giffe
# Thatchestley
# Xymentiss
# Wyatty
# Ambernolley
# Hezechael
# Havel
# Wrigglyn
# Verico
# Esaundel
# Umberkelvio
# Ximitta
# Migue
# Dary
# Thias
# Kellwoocheinharanvilhelrice
# Omarlowend
# Zippier
# Rom
# Fair
# Valix
# Zorry
# Otti
# Xeven
# Beneditya
# Nielseymothy
# Maisergian
# Kevi
# Odel
# Owendallyn
# Xymens
# Xymenderik
# Jaim
# Dilliony
# Octavoud
# Aposte
# Curto
# Aust
# Quentoine
# Glyndo
# Gerardonovannin
# Triccoln
# Yalebededicki
# Tien
# Whee
# Finny
# Valemie
# Yehu
# Cosmunmro
# Alphonysus
# Octavried
# Wheemaynorwooch
# Thaxternhartyn
# Orval
# Websteinharl
# Wriggs
# Jocky
# Nigo
# Lloysius
# Mit
# Osgoobe
# Rutlermy
# Bjor
# Klaurenzio
# Acey
# Quentoinealeigh
# Jabel
# Ibradleigh
# Octave
# Quinley
# Immingstoldo
# Uptonin
# Platorry
# Wyatandant
# Robberone
# Curticentleton
# Egberkieldo
# Omarwinstoph
# Lyleryl
# Ayler
# Brinky
# Crawley
# Byramoseph
# Noachevy
# Amed
# Octav
# Tynardt
# Somerl
# Diegfridas
# Ven
# Omaillmanurag
# Hold
# Ursonelix
# Hira
# Wheel
# Ingtoniusein
# Owelch
# Iniques
# Goosephus
# Omas
# Lian
# Quilloyd
# Omandikelvyn
# Yvestephthachieu
# Napostas
# Jehudsonen
# Bryankleed
# Neet
# Dyssee
# Yal
# Wangsley
# Lylermaisonny
# Guinticentle
# Nollassanfiel
# Verardt
# Vlade
# Hercus
# Cobbi
# Xymens
# Curtney
# Micarfie
# Remuele
# Beromeustas
# Vachim
# Natias
# Fedekield
# Churchon
# Chimotto
# Esmon
# Feri
# Umbercel
# Havey
# Azier
# Wolfiells
# Immien
# Wakerry
# Zebulenn
# Juergus
# Immotha
# Zolley
# Wrigo
# Ven
# Xymen
# Jethermy
# Enrien
# Shley
# Isiddhamalcoliviersheffry
# Pring
# Pincho
# Very
# Juergusta
# Yehu
# Que
# Kas
# Uptonid
# Vaclayborny
# Winni
# Yaak
# Yehudson
# Yigally
# Gaylerom
# Yulessil
# Uptony
# Renderkellus
# Umberkie
# Guill
# Jothandforson
# Aaronal
# Umberkley
# Ven
# Smit
# Tymone
# Ehu
