# %%
from collections import defaultdict
import numpy as np

# %%
names = open('male.txt').readlines()[6:]
names = map(lambda name:name[0:-1], names)
names = map(lambda name:name.lower(), names)

# %%
def build_model(data, deg=1):
    freq = defaultdict(lambda:defaultdict(float))
    for element in data:
        element = "^" * deg + element + "$"
        for i in range(deg, len(element)):
            freq[element[i - deg:i]][element[i]] += 1
    sum_freqs = {}
    for k, v in freq.items():
        sum_freqs[k] = sum(nb for nb in v.values())
        for kprev in freq[k].keys():
            freq[k][kprev] = float(freq[k][kprev]) / sum_freqs[k]
    return freq

# %%
max_deg = 3
models = []
for deg in range(max_deg, 0, -1):
    print(deg)
    models.append((build_model(names, deg=deg), deg))
# Out:
# 3
# 2
# 1

# %%
def gen(models, max_size=300, temp=1):    
    maxdeg = max(d for m, d in models)
    s = "^" * maxdeg
    for i in range(maxdeg, maxdeg + max_size):
        pr = None
        for model, deg in models:
            prev = s[i - deg:i]
            if prev in model:
                pr = model
                break
        assert pr is not None
        chars = pr[prev].keys()
        probas = np.array(pr[prev].values())
        if temp != 1:
            probas = softmax((probas * temp)[None, :])[0]
        char_idx = np.random.multinomial(1, probas).argmax()
        char = chars[char_idx]
        s += char
        if char == "$":
            break
    return s

def softmax(w):
    maxes = np.amax(w, axis=1)
    maxes = maxes.reshape(maxes.shape[0], 1)
    e = np.exp(w - maxes)
    dist = e / np.sum(e, axis=1, keepdims=True)
    return dist

# %%
fake_names = [gen(models, temp=0.).replace('^', '').replace('$', '').capitalize() for i in range(1000)]

# %%
nb_from_training_data = sum(1 if name.lower() in names else 0 for name in fake_names)
print('Perc. generated exactly like training data : {}%'.format(100. * nb_from_training_data/len(fake_names)))
print('Perc. generated which are original : {}%'.format(100. - 100. * nb_from_training_data/len(fake_names)))
# Out:
# Perc. generated exactly like training data : 24.1%
# Perc. generated which are original : 75.9%

# %%
fake_names = [name for name in fake_names if name.lower() not in names]

# %%
for n in fake_names:
    print(n)
# Out:
# Giovan
# Dellemmetr
# Iancey
# Quillassie
# Jamiliercy
# Zipperdiet
# Fardinero
# Blakeene
# Keilldo
# Thols
# Zollaume
# Raynardecaid
# Glynd
# Goria
# Nunzie
# Dwartail
# Whitti
# Yardt
# Xymenito
# Butledgarolphe
# Voltainninod
# Titol
# Lloysius
# Ques
# Meiercy
# Quillmond
# Powe
# Nes
# Xim
# Zel
# Irwinnislad
# Werenzio
# Ant
# Evel
# Wrigor
# Ibrane
# Vaugie
# Yuric
# Nie
# Vas
# Hiraud
# Llonzo
# Quillus
# Lorey
# Yehudsonels
# Vijah
# Alstotlet
# Brichilarsonen
# Jetheus
# Ralfonsendi
# Sandie
# Neillynd
# Zechibaut
# Keened
# Milias
# Efry
# Rhet
# Obe
# Quillus
# Clelary
# Gaylin
# Nunzier
# Zollinn
# Valejan
# Kylandalt
# Forter
# Kimmani
# Frazio
# Xymened
# Xymenso
# Xevela
# Salien
# Yigaleksandley
# Tudolfy
# Tyn
# Jasonn
# Vladeustu
# Nil
# Joth
# Rits
# Chroedee
# Wojcien
# Muhamlint
# Neetf
# Xavilliam
# Hyatanwoodmanforr
# Dysses
# Oderse
# Phiner
# Weylinn
# Ichmon
# Gearc
# Lincoleg
# Gooses
# Purchashley
# Ulico
# Odellswortinod
# Hil
# Quente
# Gabraharons
# Tros
# Shayde
# Sargess
# Jimbal
# Purchilasto
# Sily
# Octavey
# Hobartis
# Ques
# Tabe
# Endan
# Uptonen
# Jimmienninos
# Umberchy
# Fabi
# Istearny
# Ores
# Hyatty
# Bharlocky
# Bjorg
# Yehu
# Thorval
# Quiggis
# Craigelijay
# Aamili
# Urbadias
# Fyodoor
# Humberharwelch
# Blarylenal
# Etie
# Swelby
# Gaverlos
# Damsayrescot
# Giral
# Octavus
# Iniquentledgarwindharmstroscardt
# Kas
# Aarollinus
# Voltairfax
# Townsen
# Agusonen
# Tates
# Yehudio
# Que
# Creinz
# Voltaily
# Esaundorio
# Xavingerharvy
# Teodorio
# Llel
# Vladair
# Tullynd
# Napostanwoodroscott
# Srinklintus
# Drea
# Zer
# Renziercy
# Urisonnibaldwinfreece
# Yigalejandforbin
# Fitzgerey
# Wellyndolph
# Pres
# Ephael
# Yanklyndharcia
# Frie
# Din
# Kos
# Raudionifieler
# Jedetheustu
# Erriss
# Bjorniellicio
# Samsey
# Ozzier
# Lainealey
# Kos
# Zollang
# Leed
# Ulbernstoph
# Swelby
# Nivalen
# Ebedetherwinthon
# Ody
# Owendrs
# Yurice
# Immittakeefe
# Nevilheler
# Timeo
# Yigaleb
# Juani
# Puffitzgericho
# Yacob
# Octavo
# Quinch
# Yehud
# Omas
# Philbur
# Fitzgernie
# Lianos
# Bearniel
# Mois
# Aratesergessand
# Vladairfax
# Glebaulo
# Ques
# Drus
# Vladith
# Fair
# Xavis
# Scottonysus
# Xevelt
# Obaldis
# Istorpe
# Ario
# Fazelihu
# Dafforbain
# Ivannan
# Chrietroy
# Owendrzej
# Swelbie
# Piggs
# Giralphussee
# Urst
# Avells
# John-piett
# Wyereynan
# Colivas
# Obarbanuranz
# Bhartleed
# Rhet
# Bustafa
# Kyler
# Xaviusepparromain
# Uptonishelt
# Fard
# Bal
# Apold
# Pagenerd
# Jephusseinz
# Rhetta
# Zolloyd
# Hold
# Dra
# Guillon
# Iniques
# Ques
# Aylinoe
# Augusone
# Hussee
# Umbernese
# Nealsonen
# Vainn
# Fridas
# Quinten
# Llo
# Fith
# Hendello
# Zorr
# Zeustos
# Mit
# Claytonelsonen
# Ulberolph
# Kiptonin
# Cameyers
# Rinklins
# Warisergie
# Durwoochanurag
# Yardney
# Zorri
# Obinstof
# Odysonnorbes
# Drustafa
# Lylermitty
# Xavingerikki
# Uptonn
# Kevar
# Newtone
# Quiglyn
# Wiltonen
# Udah
# Mayes
# Fabiancroft
# Kraim
# Till
# Enry
# Som
# Odysone
# Acey
# Genes
# Immy
# Zorrielliancischuylessandal
# Quillmoth
# Ximeon
# Meyerey
# Spertray
# Uptoni
# Vladaird
# Trius
# Wrigginslowelch
# Octavus
# Xymenaton
# Otissy
# Homasonnibaude
# Clain
# Vaclaume
# Damsonn
# Kurtice
# Hilias
# Wey
# Wojcien
# Creinhold
# Fabi
# Fabiah
# Kleed
# Ishop
# Crawfordy
# Rhet
# Quinleightonysus
# Xymenson
# Virgei
# Bharvy
# Ryanandanita
# Quinthonysus
# Havenkat
# Dmit
# Taleksan
# Fith
# Gomew
# Trumanurag
# Zorried
# Alsh
# Yehu
# Tho
# Zipp
# Clinus
# Prencio
# Aaro
# Yuricio
# Quillon
# Ximeonar
# Flyndo
# Cainealonstanley
# Newtonysus
# Dor
# Nahul
# Philian
# Engtonifiel
# Thieu
# Sternen
# Vas
# Nunziercivanurag
# Ezeke
# Owelbathias
# Creinri
# Loveramorgangelothornie
# Kraimenter
# Vitos
# Yurisergust
# Niccolm
# Curtney
# Umbercia
# Irwiniquents
# Masonerdiegfried
# Glyndorisoneromas
# Rhettake
# Abdulkariedrowler
# Jeffen
# Ayler
# Kostherson
# Jethadly
# Shum
# Fre
# Quigmunmro
# Munroyal
# Ichaeus
# Xymen
# Liott
# Hilt
# Quinal
# Earardney
# Love
# Peytone
# Yehu
# Yurietey
# Juergean
# Mikells
# Yurits
# Clydenedy
# Calduste
# Crises
# Omas
# Kylarkus
# Ichy
# Omarioniface
# Dudlerolfonso
# Efrane
# Byronse
# Udah
# Pier
# Fult
# Theustephernandley
# Setheley
# Caesarges
# Nevingran
# Fazel
# Niallew
# Tobinkeem
# Immannorran
# Ques
# Octavromart
# Immy
# Anus
# Hasey
# Llo
# Ore
# Blayborise
# Wyer
# Yehudigelot
# Elrico
# Migue
# Hughance
# Voltailermy
# Geneddiuseinz
# Zacken
# Juliotr
# Nic
# Octaverndie
# Yehud
# Mohamusta
# Nunziercy
# Made
# Zollel
# Curtney
# Jessanfores
# Swendan
# Yehu
# Bor
# Oberhar
# Aamiscoe
# Ven
# Immie
# Trumanny
# Xymenat
# Ebenji
# Kraim
# Bonid
# Ebengt
# Bal
# Vitol
# Pertranso
# Kylardinoel
# Ewarn
# Xim
# Hakimman
# Sylvestleigh
# Matiuseppertol
# Que
# Niallic
# Guillo
# Rilu
# Hilas
# Que
# Yaakob
# Svenkat
# Ulricho
# Wylielerminigelihu
# Roicentissy
# Holos
# Owe
# Puffinnibaltonysus
# Xymendrie
# Krishee
# Ulis
# Curtney
# Prance
# Vladith
# Kita
# Uptonnislawerel
# Xim
# Etiennestley
# Weid
# Gabez
# Uptonishna
# Pembron
# Wadswolfy
# Xenoche
# Gret
# Hudith
# Kraime
# Cyrustace
# Crawforbes
# Michieu
# Immad
# Xavierri
# Mohana
# Virgearclay
# Deaneelermy
# Skelvis
# Ryanky
# Liardecai
# Lexandleightole
# Quigmarim
# Ear
# Dudleigh
# Yvestebastin
# Whitt
# Dmittakeenest
# Kipp
# Cour
# Bjor
# Turgess
# Bharly
# Yvesten
# Dmith
# Efrasado
# Baxternie
# Hurwooch
# Wojcienny
# Collars
# Verikki
# Bharel
# Immie
# Wylind
# Vannibauld
# Jonn
# Hymanuragnazio
# Gunny
# Igory
# Esaun
# Eas
# Quents
# Yvestoph
# Heywoocherl
# Teado
# Olli
# Rin
# Zalmore
# Henichalmerek
# Xim
# Ximilorny
# Wolfiellus
# Quilliano
# Versethendanatel
# Lockwelsen
# Dmitt
# Yules
# Vladean-lucianos
# Yehu
# Chrish
# Inique
# Apole
# Umbert
# Millus
# Yehu
# Xymenishmaddus
# Prescoe
# Lylermy
# Curtonysus
# Dabnerol
# Drestotle
# Gaylingstof
# Urbadias
# Hebenjie
# Waker
# Efranz
# Ethrisonerdy
# Xaviuseinhold
# Byronn
# Oss
# Bhar
# Krainni
# Crishaimunmro
# Bal
# Wyliellwooch
# Nivalim
# Iainn
# Prancis
# Mylonnon
# Ashishayes
# Ryankiell
# Neilldo
# Gaily
# Gernorty
# Timothedro
# Fyodolfielsendanislade
# Umbertin
# Xymendal
# Quillem
# Irwinigo
# Kylarsifal
# Ulysseinz
# Fostaird
# Sriniverlinos
# Karsta
# Trevern
# Euclivie
# Erwood
# Yehudsonnon
# Weidery
# Ehuditya
# Ximir
# Crate
# Tor
# Ajaimunmro
# Yehu
# Octavrien
# Die
# Kraige
# Grams
# Niccolainwrigo
# Yehu
# Laytone
# Gailiam
# Nigory
# Welberkermy
# Ude
# Quillus
# Chiltonin
# Yehudie
# Yvestos
# Giralpho
# Zaleif
# Quigi
# Suttony
# Xymenitos
# Xymene
# Pembroscottoni
# Wyatty
# Rits
# Lylero
# Dmitta
# Ephus
# Azio
# Byronen
# Bin
# Curtie
# Wiatthiew
# Lyndharwelby
# Yacomo
# Miscottias
# Grovelynn
# Kley
# Tedmunroe
# Fedekiah
# Hor
# Terrek
# Shur
# Vladeasty
# Yurienny
# Frem
# Quilldonino
# Lias
# Bjornie
# Zarussein
# Fardney
# Muff
# Octavus
# Ethroedekiah
# Nedith
# Theniccarfie
# Zipp
# Ayle
# Quinley
# Zippierschelroyaleb
# Roosever
# Quentleryl
# Xavill
# Niallass
# Verardon
# Xaviddharius
# Octave
# Homarcus
# Kaleigh
# Cesau
# Bishelt
# Tearamemnon
# Ques
# Kylentoinerolaire
# Eust
# Fult
# Olainwrigh
# Acey
# Zalomonty
# Luigglyn
# Ague
# Jodinaudellswortel
# Xim
# Socrawleronny
# Shan
# Kevi
# Curtney
# Byronid
# Heywoochaborndi
# Umbertimmondsayersch
# Jimballipe
# Tylenny
# Udas
# Ikelwoodinaudigelo
# Mith
# Zollyndo
# Pranz
# Kriswordy
# Omanfrenzio
# Umberchy
# Hollynn
# Platolds
# Vilestbrossilass
# Nie
# Mer
# Timonradforentoine
# Mitchip
# Sollynn
# Jehudsonen
# Veredmunroyce
# Ven
# Denislawtonn
# Kincy
# Jimbaltere
# Byrong
# Platonnibaudige
# Odiet
# Fer
# Har
# Zorrylen
# Obit
# Gillmarc
# Vine
# Klauste
# Nunzie
# Kurtineromy
# Uristofericcarson
# Iano
# Bjory
# Fultonishel
# Earletchealy
# Sey
# Cesargean-chrop
# Urbancroft
# Freynand
# Hymien
# Juli
# Ximilt
# Quenternstacey
# Xavi
# Kley
# Zipp
# Partice
# Glyn
# Bjorde
# Zarus
# Oscaredmundellyn
# Gamasonnibaut
# Fre
# Edselix
# Tonysus
# Yurison
# Uptony
# Bjor
# Quiggy
# Jockwellonny
